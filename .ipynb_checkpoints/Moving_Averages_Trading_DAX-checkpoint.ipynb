# %% [markdown]
# # Trading German Stocks Based on Moving Average Signals

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas_datareader import data
from datetime import datetime
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
# Define start and end date
start = datetime(2010, 8, 10)
end = datetime(2020, 8, 12)

# %%
# Create a list of ticker symbols of stocks in the DAX
simple_symbols = ['1COV', 'ADS', 'ALV', 'BAS', 'BAYN', 'BEI', 'BMW', 'CON', 'DAI', 'DB1', 'DBK', 'DPW', 'DTE', 'DWNI', 'EOAN', 
              'FME', 'FRE', 'HEI', 'HEN3', 'IFX', 'LIN', 'MRK', 'MTX', 'MUV2', 'RWE', 'SAP', 'SIE', 'VNA', 'VOW3', 'WDI']

# %%
# The DAX symbols actually have  '.DE' at the end so let's add that
dax_symbols = [x + '.DE' for x in simple_symbols]

# %%
# Import the adjusted closing prices for these stocks from Yahoo Finance
closing_prices = data.DataReader(dax_symbols, data_source='yahoo', start=start, end=end)['Adj Close']

# %%
# Inspect the first 5 rows
closing_prices.head()
# Out:
# Symbols       1COV.DE     ADS.DE      ALV.DE     BAS.DE    BAYN.DE     BEI.DE  \
# Date
# 2016-01-04  25.909983  80.298233  116.258247  50.431751  92.232994  78.003090
# 2016-01-05  25.611298  80.023048  116.630875  50.148174  92.399269  78.849281
# 2016-01-06  25.376333  79.096611  117.003494  49.312374  91.069992  78.339645
# 2016-01-07  24.532045  77.867455  114.581436  48.110905  88.744843  76.426102
# 2016-01-08  23.966534  76.546570  113.128227  47.521362  86.293945  76.233788
#
# Symbols        BMW.DE      CON.DE     DAI.DE     DB1.DE  ...     LIN.DE  \
# Date                                                     ...
# 2016-01-04  73.104820  175.963272  55.673573  69.283241  ...  53.800274
# 2016-01-05  72.764061  177.066620  55.666012  69.070145  ...  53.800274
# 2016-01-06  70.354965  171.468170  54.252247  68.208878  ...  53.800274
# 2016-01-07  67.708130  167.299973  52.165627  66.584015  ...  53.800274
# 2016-01-08  66.123215  165.747101  51.553246  66.051277  ...  53.800274
#
# Symbols        MRK.DE     MTX.DE     MUV2.DE    RWE.DE     SAP.DE     SIE.DE  \
# Date
# 2016-01-04  78.851494  80.206566  141.925018  9.155697  64.671074  71.897011
# 2016-01-05  80.196960  80.461723  141.447037  9.349246  65.449905  72.350945
# 2016-01-06  79.080315  79.668953  141.845367  9.395529  66.018013  72.065132
# 2016-01-07  76.554138  77.928497  139.216385  9.138865  65.367447  70.686539
# 2016-01-08  76.069031  77.126617  137.702713  8.953733  65.101730  70.198990
#
# Symbols        VNA.DE     VOW3.DE     WDI.DE
# Date
# 2016-01-04  22.862490  115.056900  44.991322
# 2016-01-05  23.015709  110.505600  45.224255
# 2016-01-06  22.539492  108.229942  45.774380
# 2016-01-07  22.117107  104.679939  45.080524
# 2016-01-08  21.765123  104.770950  44.892200
#
# [5 rows x 30 columns]

# %%
# Inspect how many columns we have
len(closing_prices.columns)
# Out:
# 30

# %%
# Let's also have a quick look at all price movements in a normalised fashion
normalised = closing_prices / closing_prices.iloc[0]
normalised.plot(figsize=(20,10))

# %%
# Let's get a closer look at one of these individual stocks, Adidas
closing_prices['DTE.DE'].plot(grid=True, figsize=(20,10))

# %%
# Extract a new DataFrame to be used for in-depth analysis of Deutsche Telekom
tel = pd.DataFrame(closing_prices['DTE.DE'].copy())
telecom = tel.rename(columns={'DTE.DE': 'Adj Closing'})
telecom.head()
# Out:
#             Adj Closing
# Date
# 2016-01-04    11.205934
# 2016-01-05    11.171000
# 2016-01-06    11.240864
# 2016-01-07    11.171000
# 2016-01-08    11.006824

# %%
# Create list of different moving averages to be used
moving_avgs = [10, 20, 50, 100, 200]

# %%
for avg in moving_avgs:
    telecom[str(avg) + 'd'] = np.round(telecom['Adj Closing'].rolling(avg).mean(), 2)

# %%
telecom.tail()
# Out:
#             Adj Closing    10d    20d    50d   100d   250d
# Date
# 2019-12-19    13.448697  13.57  13.67  14.01  13.86  13.57
# 2019-12-20    13.510765  13.54  13.65  13.99  13.86  13.57
# 2019-12-23    13.435919  13.52  13.64  13.98  13.86  13.57
# 2019-12-27    13.432266  13.50  13.62  13.96  13.86  13.57
# 2019-12-30    13.299004  13.47  13.59  13.94  13.86  13.57

# %%
# Plot Adidas stock price with 50 and 250 day moving averages
telecom[['Adj Closing', '50d', '250d']].plot(grid=True, figsize=(20,15))
